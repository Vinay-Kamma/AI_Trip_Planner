# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# %%
llm.invoke("Hello, world!")
# Out:
# AIMessage(content="Hello! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 39, 'total_tokens': 64, 'completion_time': 0.036215946, 'completion_tokens_details': None, 'prompt_time': 0.001709, 'prompt_tokens_details': None, 'queue_time': 0.16198572, 'total_time': 0.037924946}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b1b5c-3253-7cc3-a0e8-3b53b32958b3-0', usage_metadata={'input_tokens': 39, 'output_tokens': 25, 'total_tokens': 64})
